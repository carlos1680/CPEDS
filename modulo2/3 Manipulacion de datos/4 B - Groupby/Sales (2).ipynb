# %%
P: ¿Cuánto se ganó en 2019?
P: ¿Cuál fue el mejor mes para las ventas? ¿Cuánto se ganó ese mes?
P: ¿Qué ciudad tuvo el mayor número de ventas?
P: ¿A qué hora debemos mostrar publicidad para maximizar probabilidad de que el cliente compre el producto?
P: ¿Qué producto vendió más? ¿Por qué crees que vendió más?

# %%
import pandas as pd
import numpy as np

# %%
v_enero = pd.read_csv("Sales_January_2019 (1).csv",delimiter=',', decimal='.')
v_febrero = pd.read_csv("Sales_February_2019 (1).csv",delimiter=',', decimal='.')
v_marzo = pd.read_csv("Sales_March_2019 (1).csv",delimiter=',', decimal='.')
v_abril = pd.read_csv("Sales_April_2019 (1).csv",delimiter=',', decimal='.')
v_mayo = pd.read_csv("Sales_May_2019 (1).csv",delimiter=',', decimal='.')
v_junio = pd.read_csv("Sales_June_2019 (1).csv", delimiter=',', decimal='.')
v_julio = pd.read_csv("Sales_July_2019 (1).csv",delimiter=',', decimal='.')
v_agosto = pd.read_csv("Sales_August_2019 (1).csv",delimiter=',', decimal='.')
v_setiembre = pd.read_csv("Sales_September_2019 (1).csv",delimiter=',', decimal='.')
v_octubre = pd.read_csv("Sales_October_2019 (1).csv", delimiter=',', decimal='.')
v_noviembre = pd.read_csv("Sales_November_2019 (1).csv", delimiter=',', decimal='.')
v_diciembre = pd.read_csv("Sales_December_2019 (1).csv", delimiter=',', decimal='.')


v_febrero.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   150502                    iPhone                1        700
# 1   150503     AA Batteries (4-pack)                1       3.84
# 2   150504    27in 4K Gaming Monitor                1     389.99
# 3   150505  Lightning Charging Cable                1      14.95
# 4   150506     AA Batteries (4-pack)                2       3.84
#
#        Order Date                     Purchase Address
# 0  02/18/19 01:35    866 Spruce St, Portland, ME 04101
# 1  02/13/19 07:24  18 13th St, San Francisco, CA 94016
# 2  02/18/19 09:46   52 6th St, New York City, NY 10001
# 3  02/02/19 16:47     129 Cherry St, Atlanta, GA 30301
# 4  02/28/19 20:32    548 Lincoln St, Seattle, WA 98101

# %%
v_febrero.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   150502                    iPhone                1        700
# 1   150503     AA Batteries (4-pack)                1       3.84
# 2   150504    27in 4K Gaming Monitor                1     389.99
# 3   150505  Lightning Charging Cable                1      14.95
# 4   150506     AA Batteries (4-pack)                2       3.84
#
#        Order Date                     Purchase Address
# 0  02/18/19 01:35    866 Spruce St, Portland, ME 04101
# 1  02/13/19 07:24  18 13th St, San Francisco, CA 94016
# 2  02/18/19 09:46   52 6th St, New York City, NY 10001
# 3  02/02/19 16:47     129 Cherry St, Atlanta, GA 30301
# 4  02/28/19 20:32    548 Lincoln St, Seattle, WA 98101

# %%
v_anuales=pd.concat([v_enero,v_febrero,v_marzo,v_abril,v_mayo,v_junio,v_julio,v_agosto,v_setiembre,v_octubre,v_noviembre,v_diciembre],ignore_index=True)
v_anuales.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order Date                       Purchase Address
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301

# %%
v_anuales.shape
# Out:
# (186850, 6)

# %%
v_anuales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186850 entries, 0 to 186849
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 8.6+ MB

# %%
v_anuales.isnull().sum()
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# dtype: int64

# %%
v_anuales_sin_nulos = v_anuales.dropna()

# %%
v_anuales_sin_nulos.shape
# Out:
# (186305, 6)

# %%
v_anuales_sin_nulos["Price Each"].unique()
# Out:
# array(['700', '14.95', '11.99', '149.99', '2.99', '389.99', '11.95',
#        '99.99', '150', '1700', '300', '400', '3.84', '600', '109.99',
#        '379.99', '999.99', '600.0', 'Price Each', '700.0', '150.0',
#        '300.0', '1700.0', '400.0'], dtype=object)

# %%
v_anuales_sin_nulos = v_anuales_sin_nulos.drop(
    v_anuales_sin_nulos[v_anuales_sin_nulos["Price Each"] == 'Price Each'].index)

# %%
v_anuales_sin_nulos["Price Each"].unique()
# Out:
# array(['700', '14.95', '11.99', '149.99', '2.99', '389.99', '11.95',
#        '99.99', '150', '1700', '300', '400', '3.84', '600', '109.99',
#        '379.99', '999.99', '600.0', '700.0', '150.0', '300.0', '1700.0',
#        '400.0'], dtype=object)

# %%
v_anuales_sin_nulos["Price Each"] = v_anuales_sin_nulos["Price Each"].astype(
    'float')

# %%
v_anuales_sin_nulos.dtypes
# Out:
# Order ID             object
# Product              object
# Quantity Ordered     object
# Price Each          float64
# Order Date           object
# Purchase Address     object
# dtype: object

# %%
v_anuales_sin_nulos["Quantity Ordered"].unique()
# Out:
# array(['1', '2', '3', '5', '4', '7', '6', '9', '8'], dtype=object)

# %%
v_anuales_sin_nulos["Quantity Ordered"] = v_anuales_sin_nulos["Quantity Ordered"].astype(
    'float')

# %%
v_anuales_sin_nulos.dtypes
# Out:
# Order ID             object
# Product              object
# Quantity Ordered    float64
# Price Each          float64
# Order Date           object
# Purchase Address     object
# dtype: object

# %%
v_anuales_sin_nulos["Product"].unique()
# Out:
# array(['iPhone', 'Lightning Charging Cable', 'Wired Headphones',
#        '27in FHD Monitor', 'AAA Batteries (4-pack)',
#        '27in 4K Gaming Monitor', 'USB-C Charging Cable',
#        'Bose SoundSport Headphones', 'Apple Airpods Headphones',
#        'Macbook Pro Laptop', 'Flatscreen TV', 'Vareebadd Phone',
#        'AA Batteries (4-pack)', 'Google Phone', '20in Monitor',
#        '34in Ultrawide Monitor', 'ThinkPad Laptop', 'LG Dryer',
#        'LG Washing Machine'], dtype=object)

# %%
v_anuales_sin_nulos["Product"]= v_anuales_sin_nulos["Product"].astype(
    'category')

# %%
v_anuales_sin_nulos.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone               1.0      700.00
# 1   141235  Lightning Charging Cable               1.0       14.95
# 2   141236          Wired Headphones               2.0       11.99
# 3   141237          27in FHD Monitor               1.0      149.99
# 4   141238          Wired Headphones               1.0       11.99
#
#        Order Date                       Purchase Address
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301

# %%
v_anuales_sin_nulos["Order Date"] = pd.to_datetime(v_anuales_sin_nulos['Order Date'], format="mixed")
#pd.to_datetime(df['Fecha'], format='%m/%d/%y %H:%M')

# %%
v_anuales_sin_nulos["Purchase Address"].unique()
# Out:
# array(['944 Walnut St, Boston, MA 02215',
#        '185 Maple St, Portland, OR 97035',
#        '538 Adams St, San Francisco, CA 94016', ...,
#        '273 Wilson St, Seattle, WA 98101',
#        '778 River St, Dallas, TX 75001',
#        '747 Chestnut St, Los Angeles, CA 90001'], dtype=object)

# %%
v_anuales_sin_nulos[["calle","ciudad","codigo_postal"]]=v_anuales_sin_nulos["Purchase Address"].str.split(",",expand = True)
v_anuales_sin_nulos.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone               1.0      700.00
# 1   141235  Lightning Charging Cable               1.0       14.95
# 2   141236          Wired Headphones               2.0       11.99
# 3   141237          27in FHD Monitor               1.0      149.99
# 4   141238          Wired Headphones               1.0       11.99
#
#            Order Date                       Purchase Address          calle  \
# 0 2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215  944 Walnut St
# 1 2019-01-28 14:15:00       185 Maple St, Portland, OR 97035   185 Maple St
# 2 2019-01-17 13:33:00  538 Adams St, San Francisco, CA 94016   538 Adams St
# 3 2019-01-05 20:33:00     738 10th St, Los Angeles, CA 90001    738 10th St
# 4 2019-01-25 11:59:00          387 10th St, Austin, TX 73301    387 10th St
#
#            ciudad codigo_postal
# 0          Boston      MA 02215
# 1        Portland      OR 97035
# 2   San Francisco      CA 94016
# 3     Los Angeles      CA 90001
# 4          Austin      TX 73301

# %%
v_anuales_sin_nulos.duplicated().value_counts()
# Out:
# False    185686
# True        264
# Name: count, dtype: int64

# %%
v_anuales_sin_nulos[v_anuales_sin_nulos.duplicated()].sort_values(by="Product")
# Out:
#        Order ID                 Product  Quantity Ordered  Price Each  \
# 55179    193916            20in Monitor               1.0      109.99
# 31508    171322            20in Monitor               1.0      109.99
# 141865   276692            20in Monitor               1.0      109.99
# 175366   308671  27in 4K Gaming Monitor               1.0      389.99
# 173046   306458  27in 4K Gaming Monitor               1.0      389.99
# ...         ...                     ...               ...         ...
# 89512    226625        Wired Headphones               1.0       11.99
# 171031   304531        Wired Headphones               1.0       11.99
# 56375    195045        Wired Headphones               1.0       11.99
# 77333    214976                  iPhone               1.0      700.00
# 10165    150925                  iPhone               1.0      700.00
#
#                 Order Date                         Purchase Address  \
# 55179  2019-04-18 12:59:00          653 Cherry St, Dallas, TX 75001
# 31508  2019-03-15 13:45:00        357 Meadow St, Portland, ME 04101
# 141865 2019-10-23 10:52:00          939 River St, Atlanta, GA 30301
# 175366 2019-12-28 10:52:00  773 Johnson St, San Francisco, CA 94016
# 173046 2019-12-22 11:27:00           641 West St, Atlanta, GA 30301
# ...                    ...                                      ...
# 89512  2019-07-15 23:06:00   553 Willow St, San Francisco, CA 94016
# 171031 2019-12-27 00:44:00    306 Jackson St, Los Angeles, CA 90001
# 56375  2019-05-24 02:22:00       95 Jefferson St, Atlanta, GA 30301
# 77333  2019-06-24 23:41:00      287 6th St, San Francisco, CA 94016
# 10165  2019-02-07 17:43:00             784 Elm St, Boston, MA 02215
#
#                   calle          ciudad codigo_postal
# 55179     653 Cherry St          Dallas      TX 75001
# 31508     357 Meadow St        Portland      ME 04101
# 141865     939 River St         Atlanta      GA 30301
# 175366   773 Johnson St   San Francisco      CA 94016
# 173046      641 West St         Atlanta      GA 30301
# ...                 ...             ...           ...
# 89512     553 Willow St   San Francisco      CA 94016
# 171031   306 Jackson St     Los Angeles      CA 90001
# 56375   95 Jefferson St         Atlanta      GA 30301
# 77333        287 6th St   San Francisco      CA 94016
# 10165        784 Elm St          Boston      MA 02215
#
# [264 rows x 9 columns]

# %%
v_anuales_sin_nulos = v_anuales_sin_nulos.drop_duplicates()
v_anuales_sin_nulos.shape
# Out:
# (185686, 9)

# %%
v_anuales_sin_nulos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 185686 entries, 0 to 186849
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185686 non-null  int32
#  1   Product           185686 non-null  category
#  2   Quantity Ordered  185686 non-null  float64
#  3   Price Each        185686 non-null  float64
#  4   Order Date        185686 non-null  datetime64[ns]
#  5   Purchase Address  185686 non-null  object
#  6   calle             185686 non-null  object
#  7   ciudad            185686 non-null  object
#  8   codigo_postal     185686 non-null  object
# dtypes: category(1), datetime64[ns](1), float64(2), int32(1), object(4)
# memory usage: 12.2+ MB

# %%
v_anuales_sin_nulos["Order ID"]= v_anuales_sin_nulos["Order ID"].astype(
    'int')

# %%
v_anuales_sin_nulos["Quantity Ordered"]= v_anuales_sin_nulos["Quantity Ordered"].astype(
    'int')

# %%
v_anuales_sin_nulos.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# calle               0
# ciudad              0
# codigo_postal       0
# dtype: int64

# %%
#P: ¿Cuánto se ganó en 2019?
v_anuales_sin_nulos['año']= v_anuales_sin_nulos['Order Date'].dt.year

# %%
v_anuales_sin_nulos['venta_total']= v_anuales_sin_nulos['Quantity Ordered']*v_anuales_sin_nulos['Price Each']

# %%
condicion2019 = v_anuales_sin_nulos["año"]== 2019
#v_anuales_sin_nulos.loc[(condicion2019),["venta_total"]].sum() # Funciona
v_anuales_sin_nulos[(condicion2019)]["venta_total"].sum() # Funciona
# Out:
# 34456867.64999999

# %%
# P: ¿Cuál fue el mejor mes para las ventas? ¿Cuánto se ganó ese mes?
v_anuales_sin_nulos['mes']= v_anuales_sin_nulos['Order Date'].dt.month
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File f:\Personal\django\CPE\CPEDS\envWindows\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('mes', 'venta_total')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[57], line 3
#       1 # P: ¿Cuál fue el mejor mes para las ventas? ¿Cuánto se ganó ese mes?
#       2 v_anuales_sin_nulos['mes']= v_anuales_sin_nulos['Order Date'].dt.month
# ----> 3 v_anuales_sin_nulos['mes','venta_total'].groupby(('mes'), key=None).sum()
#
# File f:\Personal\django\CPE\CPEDS\envWindows\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File f:\Personal\django\CPE\CPEDS\envWindows\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: ('mes', 'venta_total')

# %%
v_anuales_sin_nulos.head()
# Out:
#    Order ID                   Product  Quantity Ordered  Price Each  \
# 0    141234                    iPhone                 1      700.00
# 1    141235  Lightning Charging Cable                 1       14.95
# 2    141236          Wired Headphones                 2       11.99
# 3    141237          27in FHD Monitor                 1      149.99
# 4    141238          Wired Headphones                 1       11.99
#
#            Order Date                       Purchase Address          calle  \
# 0 2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215  944 Walnut St
# 1 2019-01-28 14:15:00       185 Maple St, Portland, OR 97035   185 Maple St
# 2 2019-01-17 13:33:00  538 Adams St, San Francisco, CA 94016   538 Adams St
# 3 2019-01-05 20:33:00     738 10th St, Los Angeles, CA 90001    738 10th St
# 4 2019-01-25 11:59:00          387 10th St, Austin, TX 73301    387 10th St
#
#            ciudad codigo_postal   año  venta_total  mes
# 0          Boston      MA 02215  2019       700.00    1
# 1        Portland      OR 97035  2019        14.95    1
# 2   San Francisco      CA 94016  2019        23.98    1
# 3     Los Angeles      CA 90001  2019       149.99    1
# 4          Austin      TX 73301  2019        11.99    1

# %%
v_anuales_sin_nulos[['mes','venta_total','Quantity Ordered']].groupby(('mes')).sum().sort_values(by='venta_total',ascending= False)
# Out:
#      venta_total  Quantity Ordered
# mes
# 12    4608295.70             28074
# 10    3734777.86             22669
# 4     3389217.98             20536
# 11    3197875.05             19769
# 5     3150616.23             18653
# 3     2804973.35             16979
# 7     2646461.32             16054
# 6     2576280.15             15234
# 8     2241083.37             13429
# 2     2200078.08             13431
# 9     2094465.69             13091
# 1     1821413.16             10893

# %%
#P: ¿Qué ciudad tuvo el mayor número de ventas?
v_anuales_sin_nulos[['ciudad','Order ID']].groupby(('ciudad')).count().sort_values(by='Order ID',ascending= False)
# Out:
#                Order ID
# ciudad
# San Francisco     44662
# Los Angeles       29564
# New York City     24847
# Boston            19901
# Atlanta           14863
# Dallas            14797
# Seattle           14713
# Portland          12449
# Austin             9890

# %%
# P: ¿A qué hora debemos mostrar publicidad para maximizar probabilidad de que el cliente compre el producto?
v_anuales_sin_nulos['hora']= v_anuales_sin_nulos['Order Date'].dt.hour

# %%
v_anuales_sin_nulos[['hora','Order ID']].groupby(('hora')).count().sort_values(by='Order ID',ascending= False)
# Out:
#       Order ID
# hora
# 19       12886
# 12       12573
# 11       12392
# 18       12263
# 20       12218
# 13       12115
# 14       10965
# 10       10929
# 21       10905
# 17       10884
# 16       10359
# 15       10159
# 22        8808
# 9         8740
# 23        6262
# 8         6252
# 7         4002
# 0         3902
# 6         2481
# 1         2347
# 5         1320
# 2         1242
# 4          852
# 3          830

# %%
v_anuales_sin_nulos[['hora','venta_total']].groupby(('hora')).count().sort_values(by='venta_total',ascending= False)
# Out:
#       venta_total
# hora
# 19          12886
# 12          12573
# 11          12392
# 18          12263
# 20          12218
# 13          12115
# 14          10965
# 10          10929
# 21          10905
# 17          10884
# 16          10359
# 15          10159
# 22           8808
# 9            8740
# 23           6262
# 8            6252
# 7            4002
# 0            3902
# 6            2481
# 1            2347
# 5            1320
# 2            1242
# 4             852
# 3             830

# %%
# P: ¿Qué producto vendió más? ¿Por qué crees que vendió más?

v_anuales_sin_nulos[['Product','Order ID']].groupby(('Product')).count().sort_values(by='Order ID',ascending= False)
# Out:
# C:\Users\carlos\AppData\Local\Temp\ipykernel_13052\906530311.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   v_anuales_sin_nulos[['Product','Order ID']].groupby(('Product')).count().sort_values(by='Order ID',ascending= False)
#                             Order ID
# Product
# USB-C Charging Cable           21859
# Lightning Charging Cable       21610
# AAA Batteries (4-pack)         20612
# AA Batteries (4-pack)          20558
# Wired Headphones               18849
# Apple Airpods Headphones       15525
# Bose SoundSport Headphones     13298
# 27in FHD Monitor                7498
# iPhone                          6840
# 27in 4K Gaming Monitor          6225
# 34in Ultrawide Monitor          6174
# Google Phone                    5522
# Flatscreen TV                   4794
# Macbook Pro Laptop              4721
# ThinkPad Laptop                 4126
# 20in Monitor                    4098
# Vareebadd Phone                 2065
# LG Washing Machine               666
# LG Dryer                         646

# %%
print("Entendemos que USB-C Charging Cable es el mas vendido por su menor vida util, precio, utilidad.")
# Out:
# Entendemos que USB-C Charging Cable es el mas vendido por su menor vida util, precio, utilidad.
