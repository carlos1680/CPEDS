# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ipc = pd.read_excel("ipc.xlsx", parse_dates= ["Mes y año"], index_col = 'Mes y año')
ipc.head()
# Out:
#                   Índice   Mensual  ...  Cuatrimestre  Semestre
# Mes y año                           ...
# 1940-01-01  4.596609e-07 -1.408451  ...      3.550296  4.477612
# 1940-02-01  4.596609e-07  0.000000  ...      2.941176  4.790419
# 1940-03-01  4.622876e-07  0.571429  ...      2.623907  4.142012
# 1940-04-01  4.596609e-07 -0.568182  ...     -1.408451  2.941176
# 1940-05-01  4.544077e-07 -1.142857  ...     -1.142857  0.874636
#
# [5 rows x 7 columns]

# %%
ipc.plot()

# %%
ipc.plot( y = 'Índice')

# %%
ipc.plot( y = ['Índice', 'Mensual'])

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('fivethirtyeight')

# %%
ipc.plot(y='Índice')

# %%
plt.style.use('dark_background')
ipc.plot(y='Índice')

# %%
plt.style.use('ggplot')
ipc.plot(y='Índice')

# %%
import numpy as np
ipc["Resultado"] = np.where(ipc["Mensual"] > 0, "Positivo", 
                            np.where(ipc["Mensual"] < 0, "Negativo",
                                     "Cero"))

# %%
ipc[["Mensual", "Resultado"]]
# Out:
#              Mensual Resultado
# Mes y año
# 1940-01-01 -1.408451  Negativo
# 1940-02-01  0.000000      Cero
# 1940-03-01  0.571429  Positivo
# 1940-04-01 -0.568182  Negativo
# 1940-05-01 -1.142857  Negativo
# ...              ...       ...
# 2020-12-01 -0.190000  Negativo
# 2021-01-01  1.600000  Positivo
# 2021-02-01  0.820000  Positivo
# 2021-03-01  0.620000  Positivo
# 2021-04-01  0.500000  Positivo
#
# [976 rows x 2 columns]

# %%
ipc["Resultado"].value_counts()
# Out:
# Positivo    848
# Negativo     99
# Cero         29
# Name: Resultado, dtype: int64

# %%
ipc["Resultado"].value_counts().plot()

# %%
ipc["Resultado"].value_counts().plot(kind = "bar")

# %%
ipc["Resultado"].value_counts().plot(kind = "barh")

# %%
media_ipc = ipc["Mensual"].mean()

def sobre_promedio(mensual):
  if mensual >= media_ipc:
    return "Sobre el promedio"
  else:
    return "Bajo el promedio"

ipc["Mensual"].apply(sobre_promedio).value_counts()
# Out:
# Bajo el promedio     605
# Sobre el promedio    371
# Name: Mensual, dtype: int64

# %%
plt.style.use("dark_background")
ipc["Mensual"].apply(sobre_promedio).value_counts().plot( kind = 'pie', legend = True)
