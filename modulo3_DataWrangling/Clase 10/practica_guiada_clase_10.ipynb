# %%
import pandas as pd

# %% [markdown]
# # 1 -  Fuzzy Matching
#
# Utilizaremos los conceptos de fuzzy matching para mejorar una variable categórica

# %%
#Primero instalemos fuzzywuzzy
# !pip install fuzzywuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# Leemos un archivo con información de los departamentos de Uruguay
fuzzy = pd.read_csv("/content/drive/MyDrive/Curso CPE Data Wrangling/Clases/Clase 10 - Manejo avanzado strings e IO datos/Ejercicio_Fuzzy.csv", encoding = "ISO-8859-1")

# %%
fuzzy.sample(6)
# Out:
#     Id Departamento  Valor
# 12  13      durazno     27
# 6    7     C. Largo     29
# 76  77        Flors     41
# 77  78       Flores     32
# 10  11      Montev.     89
# 61  62   Tacuarmebo     79

# %% [markdown]
# Tenemos un dataset de ejemplo con un campo "Departamento" ingresado de forma manual, con errores de tipeo

# %%
fuzzy['Departamento'].drop_duplicates()
# Out:
# 0         Montevideo
# 1          Canelones
# 2           San Jose
# 3            Soriano
# 4            Durazno
# 5        Cerro Largo
# 6           C. Largo
# 7            S. Jos
# 8           San Jos
# 9             Mvdeo.
# 10           Montev.
# 11           Colonia
# 12           durazno
# 14    Treinta y Tres
# 15      Treintaytres
# 16         Rio Negro
# 18          R. negro
# 19         Maldonado
# 21    Trainta y trs
# 22         maldonado
# 23             Rocha
# 24        Tacuarmebo
# 25       Tamcuaremb¢
# 26          Canelons
# 27           Artigas
# 28             Salto
# 29            Rivera
# 32          Paysand£
# 33          Paysandu
# 75           Florida
# 76             Flors
# 77            Flores
# 79         Lavalleja
# Name: Departamento, dtype: object

# %% [markdown]
# De la librería fuzzywuzzy usaremos las funciones:
#
#
# `ratio(string_1, string_2)`: calcula el ratio de coincidencia entre string_1 y string_2 usando la distancia de Levenshtein
#
# `partial_ratio(string_1, string_2)`: calcula el ratio de coincidencia tomando al string más corto como substring y buscando coincidencias parciales

# %%
# Ratio entre strings iguales
fuzz.ratio('durazno','durazno')
# Out:
# 100

# %%
# Ratio entre strings levemente distintos
fuzz.ratio('Durazno','durazno')
# Out:
# 86

# %%
# Ratio entre strings muy distintos
fuzz.ratio('durazno','Yo vivo en durazno hace años')
# Out:
# 40

# %%
# Ratio parcial entre strings muy distintos
fuzz.partial_ratio('durazno','Yo vivo en durazno hace años')
# Out:
# 100

# %% [markdown]
# Obtenemos una lista con los valores verdaderos de los departamentos.

# %%
departamentos = [
    'Montevideo',
    'Treinta y Trés',
    'Colonia',
    'Artigas',
    'Canelones',
    'Cerro Largo',
    'Durazno',
    'Flores',
    'Florida',
    'Lavalleja',
    'Maldonado',
    'Paysandú',
    'Río Negro',
    'Rivera',
    'Rocha',
    'Salto',
    'San José',
    'Soriano',
    'Tacuarembó'
]

# %% [markdown]
# Busquemos encontrar el valor más próximo para uno de los valores de nuestro dataset.
# En general es un buen procedimiento utilizar las técnicas de manipulación de strings como quitar eliminar espacios en blanco, llevar todo el texto a minuscula, etc. previo a usar las funciones de fuzzy matching funciones.

# %%
fuzzy.loc[76,'Departamento']
# Out:
# 'Flors'

# %%
depto = fuzzy.loc[76,'Departamento'].lower()
depto
# Out:
# 'flors'

# %%
max_coincidencia = 0
# Recorremos la lista de departamentos
for valor_correcto in departamentos:
  # Llevamos a minuscula
  valor_correcto = valor_correcto.lower()
  # Obtenemos el ratio de coincidencia
  coincidencia = fuzz.ratio(depto, valor_correcto)
  # Si el puntaje de la coincidencia es mayor que la vigente
  if coincidencia > max_coincidencia:
    # Guardar el valor correcto
    correccion = valor_correcto
    # Reemplazar el puntaje
    max_coincidencia = coincidencia

print(f"Para el valor {depto}, el valor correcto es {correccion} con un puntaje de {max_coincidencia}")
# Out:
# Para el valor flors, el valor correcto es flores con un puntaje de 91

# %%
for _,row in fuzzy.iterrows():
  depto = row['Departamento'].lower()
  max_coincidencia = 0
  # Recorremos la lista de departamentos
  for valor_correcto in departamentos:
    # Llevamos a minuscula
    valor_correcto = valor_correcto.lower()
    # Obtenemos el ratio de coincidencia
    coincidencia = fuzz.ratio(depto, valor_correcto)
    # Si el puntaje de la coincidencia es mayor que la vigente
    if coincidencia > max_coincidencia:
      # Guardar el valor correcto
      correccion = valor_correcto
      # Reemplazar el puntaje
      max_coincidencia = coincidencia
  if max_coincidencia < 100:
    print(f"Para el valor {depto}, el valor correcto es {correccion} con un puntaje de {max_coincidencia}")
# Out:
# Para el valor san jose, el valor correcto es san josé con un puntaje de 88
# Para el valor c. largo, el valor correcto es cerro largo con un puntaje de 74
# Para el valor s. jos, el valor correcto es san josé con un puntaje de 67
# Para el valor san jos, el valor correcto es san josé con un puntaje de 88
# Para el valor mvdeo., el valor correcto es montevideo con un puntaje de 62
# Para el valor montev., el valor correcto es montevideo con un puntaje de 71
# Para el valor treinta y tres, el valor correcto es treinta y trés con un puntaje de 93
# Para el valor treintaytres, el valor correcto es treinta y trés con un puntaje de 85
# Para el valor rio negro, el valor correcto es río negro con un puntaje de 89
# Para el valor r. negro, el valor correcto es río negro con un puntaje de 82
# Para el valor trainta y trs, el valor correcto es treinta y trés con un puntaje de 86
# Para el valor tacuarmebo, el valor correcto es tacuarembó con un puntaje de 80
# Para el valor tamcuaremb¢, el valor correcto es tacuarembó con un puntaje de 86
# Para el valor canelons, el valor correcto es canelones con un puntaje de 94
# Para el valor paysand£, el valor correcto es paysandú con un puntaje de 88
# Para el valor paysandu, el valor correcto es paysandú con un puntaje de 88
# Para el valor san jose, el valor correcto es san josé con un puntaje de 88
# Para el valor c. largo, el valor correcto es cerro largo con un puntaje de 74
# Para el valor s. jos, el valor correcto es san josé con un puntaje de 67
# Para el valor san jos, el valor correcto es san josé con un puntaje de 88
# Para el valor mvdeo., el valor correcto es montevideo con un puntaje de 62
# Para el valor montev., el valor correcto es montevideo con un puntaje de 71
# Para el valor treinta y tres, el valor correcto es treinta y trés con un puntaje de 93
# Para el valor treintaytres, el valor correcto es treinta y trés con un puntaje de 85
# Para el valor treinta y tres, el valor correcto es treinta y trés con un puntaje de 93
# Para el valor treintaytres, el valor correcto es treinta y trés con un puntaje de 85
# Para el valor rio negro, el valor correcto es río negro con un puntaje de 89
# Para el valor r. negro, el valor correcto es río negro con un puntaje de 82
# Para el valor trainta y trs, el valor correcto es treinta y trés con un puntaje de 86
# Para el valor tacuarmebo, el valor correcto es tacuarembó con un puntaje de 80
# Para el valor tamcuaremb¢, el valor correcto es tacuarembó con un puntaje de 86
# Para el valor canelons, el valor correcto es canelones con un puntaje de 94
# Para el valor paysand£, el valor correcto es paysandú con un puntaje de 88
# Para el valor paysandu, el valor correcto es paysandú con un puntaje de 88
# Para el valor san jose, el valor correcto es san josé con un puntaje de 88
# Para el valor flors, el valor correcto es flores con un puntaje de 91
# Para el valor san jose, el valor correcto es san josé con un puntaje de 88

# %% [markdown]
# # 2 - Ejercicios con expresiones regulares

# %%
entrevistas_dict = {'nombre':['Pedro', 'Celeste', 'Mariela', 'Jorge', 'Matías'],
 'fecha_nacimiento':['22-03-1994', 'Nací el 15-05-1997', '03-11-91', 'fecha nacimiento: 10-10-1998', '03-01-1999'],
 'titulo_maximo': ['Lic. Administracion', 'Ingeniera en sistemas', 'Licenciada en Economía', 'Ing. industrial', 'Biología'],
 'idiomas':['español', 'español, ingles', 'español', 'español, ingles y portugues', '4']}

# %%
entrevistas = pd.DataFrame(entrevistas_dict)

# %%
entrevistas
# Out:
#     nombre              fecha_nacimiento           titulo_maximo  \
# 0    Pedro                    22-03-1994     Lic. Administracion
# 1  Celeste            Nací el 15-05-1997   Ingeniera en sistemas
# 2  Mariela                      03-11-91  Licenciada en Economía
# 3    Jorge  fecha nacimiento: 10-10-1998         Ing. industrial
# 4   Matías                    03-01-1999                Biología
#
#                        idiomas
# 0                      español
# 1              español, ingles
# 2                      español
# 3  español, ingles y portugues
# 4                            4

# %% [markdown]
# Supongamos que queremos crear una variable limpia con la fecha de nacimiento

# %%
# Usamos el método findall 
entrevistas['fecha_nacimiento'].str.findall(pat="\d{2}-\d{2}-\d{2,4}")
# Out:
# 0    [22-03-1994]
# 1    [15-05-1997]
# 2      [03-11-91]
# 3    [10-10-1998]
# 4    [03-01-1999]
# Name: fecha_nacimiento, dtype: object

# %% [markdown]
# Ahora queremos crear una variable que nos indique si la persona estudió ingeniería

# %%
#Usamos el método contains
entrevistas['titulo_maximo'].str.contains(pat='Ing|ingenier')
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# Name: titulo_maximo, dtype: bool

# %% [markdown]
# Podemos simplificar aún más la expresión regular

# %%
entrevistas['titulo_maximo'].str.contains(pat='I|ing')
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# Name: titulo_maximo, dtype: bool

# %% [markdown]
# Ahora queremos analizar la variable de idiomas. En primer lugar queremos controlar que las personas hayan puesto un listado de idiomas y no otro dato

# %%
entrevistas['idiomas'].str.contains(pat="\d")
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# Name: idiomas, dtype: bool

# %% [markdown]
# Vemos que el último registro tiene un dato numérico, el cual no nos sirve para este análisis que queremos realizar. Procedemos a generar una variable con la lista de idiomas

# %%
entrevistas['idiomas'].str.split(pat="[,y]")
# Out:
# 0                          [español]
# 1                 [español,  ingles]
# 2                          [español]
# 3    [español,  ingles ,  portugues]
# 4                                [4]
# Name: idiomas, dtype: object

# %% [markdown]
# Si quisieramos generar una columna por cada elemento podemos utilizar el argumento `expand=True`

# %%
entrevistas['idiomas'].str.split(pat="[,y]", expand=True)
# Out:
#          0         1           2
# 0  español      None        None
# 1  español    ingles        None
# 2  español      None        None
# 3  español   ingles    portugues
# 4        4      None        None

# %% [markdown]
# # 3 - Entrada y salida de datos
#
# Vimos que existe una gran cantidad de formatos de archivos y pandas brinda métodos para leer y escribir en cada uno de ellos.
#
# Uno de los formatos más utilizados es el csv. Observemos algunos de los parámetros más usuales al leer un archivo

# %%
# Leemos el archivo de ejemplo que viene en google colab
housing_df = pd.read_csv("/content/sample_data/california_housing_train.csv")
housing_df.sample(6)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5117     -118.12     33.76                45.0       3035.0           516.0
# 944      -117.09     32.83                15.0       4138.0           636.0
# 4363     -118.02     33.96                36.0       2002.0           361.0
# 2112     -117.35     34.01                23.0       3707.0           769.0
# 6060     -118.22     33.91                28.0       1847.0           500.0
# 10288    -120.04     36.93                11.0       3606.0           699.0
#
#        population  households  median_income  median_house_value
# 5117       1127.0       527.0         7.0796            500001.0
# 944        2001.0       677.0         4.8419            264000.0
# 4363        913.0       311.0         4.5446            244700.0
# 2112       1938.0       658.0         2.7250             95300.0
# 6060       2263.0       473.0         1.5161            103200.0
# 10288      2074.0       644.0         2.6941             63300.0

# %%
housing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB

# %%
# Especificamos una columna de indice
housing_df = pd.read_csv("/content/sample_data/california_housing_train.csv", index_col='longitude')
housing_df.head(6)
# Out:
#            latitude  housing_median_age  total_rooms  total_bedrooms  \
# longitude
# -114.31       34.19                15.0       5612.0          1283.0
# -114.47       34.40                19.0       7650.0          1901.0
# -114.56       33.69                17.0        720.0           174.0
# -114.57       33.64                14.0       1501.0           337.0
# -114.57       33.57                20.0       1454.0           326.0
# -114.58       33.63                29.0       1387.0           236.0
#
#            population  households  median_income  median_house_value
# longitude
# -114.31        1015.0       472.0         1.4936             66900.0
# -114.47        1129.0       463.0         1.8200             80100.0
# -114.56         333.0       117.0         1.6509             85700.0
# -114.57         515.0       226.0         3.1917             73400.0
# -114.57         624.0       262.0         1.9250             65500.0
# -114.58         671.0       239.0         3.3438             74000.0

# %%
# Especificamos una fila como nombre de columnas
housing_df = pd.read_csv("/content/sample_data/california_housing_train.csv", header=1)
housing_df.sample(6)
# Out:
#        -114.310000  34.190000  15.000000  5612.000000  1283.000000  \
# 8085       -118.42      33.90       37.0       1576.0        345.0
# 8055       -118.42      34.05       33.0       2921.0        652.0
# 1844       -117.27      33.18        4.0       3371.0        773.0
# 12077      -121.43      38.69       28.0        927.0        165.0
# 1292       -117.15      33.02        4.0      15029.0       2279.0
# 13421      -121.94      37.26       43.0       2104.0        388.0
#
#        1015.000000  472.000000  1.493600  66900.000000
# 8085         662.0       340.0    5.3080      500001.0
# 8055        1124.0       608.0    5.0151      500001.0
# 1844        1481.0       627.0    2.9133      215700.0
# 12077        542.0       148.0    2.5000       96200.0
# 1292        5613.0      1696.0    7.2731      450400.0
# 13421       1137.0       403.0    4.9236      238000.0

# %%
# Indicamos que lea las primeras 1000 filas
housing_df = pd.read_csv("/content/sample_data/california_housing_train.csv", nrows=1000)
housing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           1000 non-null   float64
#  1   latitude            1000 non-null   float64
#  2   housing_median_age  1000 non-null   float64
#  3   total_rooms         1000 non-null   float64
#  4   total_bedrooms      1000 non-null   float64
#  5   population          1000 non-null   float64
#  6   households          1000 non-null   float64
#  7   median_income       1000 non-null   float64
#  8   median_house_value  1000 non-null   float64
# dtypes: float64(9)
# memory usage: 70.4 KB

# %% [markdown]
# Hemos viste que podemos leer archivos pasando una URL en la función correspondiente.
# Una función muy útil para leer tablas desde ciertos sitios web es `pandas.read_html(io, match)`:
#
# *   **io**: dirección o nombre del archivo
# *   **match**: string o regex para encontrar tablas particulares
#
# La función devuelve una lista de DataFrames con todas las tablas en el html.

# %%
? pd.read_html()

# %% [markdown]
# Veamos un caso de análisis para la página de Wikipedia de la [Copa Mundial de Fútbol](https://es.wikipedia.org/wiki/Copa_Mundial_de_F%C3%BAtbol)

# %%
#Busquemos ahora tablas dentro de una pagina web de wikipedia
mundial = pd.read_html('https://es.wikipedia.org/wiki/Copa_Mundial_de_F%C3%BAtbol')
print(f'Total de tablas en la pagina: {len(mundial)}')
# Out:
# Total de tablas en la pagina: 11

# %%
# Veamos la quinta tabla: tabla de goleadores del mundial
mundial[4]
# Out:
#     Pos.      Jugador[114]​   Selección  Goles  Partidos  Promedio  \
# 0    1.0     Miroslav Klose    Alemania     16        24        67
# 1    2.0            Ronaldo      Brasil     15        19        79
# 2    3.0        Gerd Müller    Alemania     14        13       108
# 3    4.0      Just Fontaine     Francia     13         6       217
# 4    5.0               Pelé      Brasil     12        14        86
# 5    6.0      Sándor Kocsis     Hungría     11         5        22
# 6    NaN   Jürgen Klinsmann    Alemania     11        17        65
# 7    8.0        Helmut Rahn    Alemania     10        10         1
# 8    NaN  Gabriel Batistuta   Argentina     10        12        83
# 9    NaN       Gary Lineker  Inglaterra     10        12        83
# 10   NaN   Teófilo Cubillas        Perú     10        13        77
# 11   NaN      Thomas Müller    Alemania     10        16        63
# 12   NaN      Grzegorz Lato     Polonia     10        20         5
#
#             Torneos jugados
# 0   2002, 2006, 2010 y 2014
# 1          1998, 2002, 2006
# 2               1970 y 1974
# 3                      1958
# 4   1958, 1962, 1966 y 1970
# 5                      1954
# 6         1990, 1994 y 1998
# 7               1954 y 1958
# 8         1994, 1998 y 2002
# 9               1986 y 1990
# 10        1970, 1978 y 1982
# 11        2010, 2014 y 2018
# 12        1974, 1978 y 1982

# %% [markdown]
# Podemos utilizar el argumento match para obtener un subconjunto de las tablas

# %%
#Traigamos la tabla del balon de oro
tabla_balon_oro = pd.read_html('https://es.wikipedia.org/wiki/Copa_Mundial_de_F%C3%BAtbol',match='Oro')
print(f'Total de tablas en la pagina: {len(tabla_balon_oro)}')
# Out:
# Total de tablas en la pagina: 1

# %%
df = tabla_balon_oro[0]
df
# Out:
#                  Copa Mundial         Balón de Oro     Equipo  \
# 0                 España 1982          Paolo Rossi     Italia
# 1                 México 1986       Diego Maradona  Argentina
# 2                 Italia 1990  Salvatore Schillaci     Italia
# 3         Estados Unidos 1994              Romário     Brasil
# 4                Francia 1998              Ronaldo     Brasil
# 5  Corea del Sur / Japón 2002          Oliver Kahn   Alemania
# 6               Alemania 2006      Zinedine Zidane    Francia
# 7              Sudáfrica 2010         Diego Forlán    Uruguay
# 8                 Brasil 2014         Lionel Messi  Argentina
# 9                  Rusia 2018          Luka Modrić    Croacia
#
#       Balón de Plata      Equipo.1        Balón de Bronce       Equipo.2
# 0             Falcão        Brasil  Karl-Heinz Rummenigge       Alemania
# 1  Harald Schumacher      Alemania   Preben Elkjær Larsen      Dinamarca
# 2    Lothar Matthäus      Alemania         Diego Maradona      Argentina
# 3     Roberto Baggio        Italia      Hristo Stoitchkov       Bulgaria
# 4        Davor Šuker       Croacia          Lilian Thuram        Francia
# 5            Ronaldo        Brasil          Hong Myung-bo  Corea del Sur
# 6    Fabio Cannavaro        Italia           Andrea Pirlo         Italia
# 7    Wesley Sneijder  Países Bajos            David Villa         España
# 8      Thomas Müller      Alemania           Arjen Robben   Países Bajos
# 9        Eden Hazard       Bélgica      Antoine Griezmann        Francia

# %% [markdown]
# ## 4 - Conexion con una **API**
#
# Veamos un muy breve ejemplo de interacción con una API

# %%
# Cargamos el módulo requests
import requests

# %%
# Vamos a consultar la api de Github de pandas
url = "https://api.github.com/repos/pandas-dev/pandas/issues"
# Realizamos una operacion GET a la url
r = requests.get(url)

# %%
r.json()[0:2]
# Out:
# [{'active_lock_reason': None,
#   'assignee': None,
#   'assignees': [],
#   'author_association': 'CONTRIBUTOR',
#   'body': 'Add Reversed so that it fulfills all properties of Sequence\r\n\r\n- [ ] closes #xxxx (Replace xxxx with the Github issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'closed_at': None,
#   'comments': 1,
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47669/comments',
#   'created_at': '2022-07-11T18:13:14Z',
#   'draft': True,
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47669/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47669',
#   'id': 1301053153,
#   'labels': [],
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47669/labels{/name}',
#   'locked': False,
#   'milestone': None,
#   'node_id': 'PR_kwDOAA0YD847NjCK',
#   'number': 47669,
#   'performed_via_github_app': None,
#   'pull_request': {'diff_url': 'https://github.com/pandas-dev/pandas/pull/47669.diff',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/47669',
#    'merged_at': None,
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/47669.patch',
#    'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/47669'},
#   'reactions': {'+1': 0,
#    '-1': 0,
#    'confused': 0,
#    'eyes': 0,
#    'heart': 0,
#    'hooray': 0,
#    'laugh': 0,
#    'rocket': 0,
#    'total_count': 0,
#    'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47669/reactions'},
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'state': 'open',
#   'state_reason': None,
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47669/timeline',
#   'title': 'ENH: Add reversed to Series',
#   'updated_at': '2022-07-11T18:15:36Z',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47669',
#   'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/5585221?v=4',
#    'events_url': 'https://api.github.com/users/bashtage/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/bashtage/followers',
#    'following_url': 'https://api.github.com/users/bashtage/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/bashtage/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/bashtage',
#    'id': 5585221,
#    'login': 'bashtage',
#    'node_id': 'MDQ6VXNlcjU1ODUyMjE=',
#    'organizations_url': 'https://api.github.com/users/bashtage/orgs',
#    'received_events_url': 'https://api.github.com/users/bashtage/received_events',
#    'repos_url': 'https://api.github.com/users/bashtage/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/bashtage/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/bashtage/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/bashtage'}},
#  {'active_lock_reason': None,
#   'assignee': None,
#   'assignees': [],
#   'author_association': 'MEMBER',
#   'body': '- [ ] closes #xxxx (Replace xxxx with the Github issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'closed_at': None,
#   'comments': 0,
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47668/comments',
#   'created_at': '2022-07-11T14:27:37Z',
#   'draft': False,
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47668/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47668',
#   'id': 1300793242,
#   'labels': [],
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47668/labels{/name}',
#   'locked': False,
#   'milestone': None,
#   'node_id': 'PR_kwDOAA0YD847MrBD',
#   'number': 47668,
#   'performed_via_github_app': None,
#   'pull_request': {'diff_url': 'https://github.com/pandas-dev/pandas/pull/47668.diff',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/47668',
#    'merged_at': None,
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/47668.patch',
#    'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/47668'},
#   'reactions': {'+1': 0,
#    '-1': 0,
#    'confused': 0,
#    'eyes': 0,
#    'heart': 0,
#    'hooray': 0,
#    'laugh': 0,
#    'rocket': 0,
#    'total_count': 0,
#    'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47668/reactions'},
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'state': 'open',
#   'state_reason': None,
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47668/timeline',
#   'title': 'ENH: TDA.__mul__ support non-nano',
#   'updated_at': '2022-07-11T15:46:23Z',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47668',
#   'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/jbrockmendel',
#    'id': 8078968,
#    'login': 'jbrockmendel',
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/jbrockmendel'}}]

# %%
# Podemos construir un dataframe con esta respuesta
pd.DataFrame(r.json())
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                            events_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                              html_url          id  \
# 0     https://github.com/pandas-dev/pandas/pull/47669  1301053153
# 1     https://github.com/pandas-dev/pandas/pull/47668  1300793242
# 2   https://github.com/pandas-dev/pandas/issues/47667  1300747628
# 3   https://github.com/pandas-dev/pandas/issues/47666  1300440361
# 4   https://github.com/pandas-dev/pandas/issues/47663  1300066443
# 5   https://github.com/pandas-dev/pandas/issues/47659  1299811423
# 6     https://github.com/pandas-dev/pandas/pull/47658  1299805679
# 7     https://github.com/pandas-dev/pandas/pull/47657  1299794113
# 8     https://github.com/pandas-dev/pandas/pull/47656  1299772229
# 9   https://github.com/pandas-dev/pandas/issues/47653  1299708940
# 10  https://github.com/pandas-dev/pandas/issues/47651  1299679998
# 11  https://github.com/pandas-dev/pandas/issues/47649  1299553850
# 12    https://github.com/pandas-dev/pandas/pull/47647  1299415800
# 13    https://github.com/pandas-dev/pandas/pull/47645  1299398856
# 14    https://github.com/pandas-dev/pandas/pull/47643  1299296038
# 15  https://github.com/pandas-dev/pandas/issues/47639  1298985414
# 16  https://github.com/pandas-dev/pandas/issues/47629  1298122325
# 17  https://github.com/pandas-dev/pandas/issues/47628  1298068445
# 18  https://github.com/pandas-dev/pandas/issues/47625  1297443400
# 19    https://github.com/pandas-dev/pandas/pull/47624  1297341949
# 20  https://github.com/pandas-dev/pandas/issues/47622  1297110248
# 21  https://github.com/pandas-dev/pandas/issues/47614  1296131334
# 22    https://github.com/pandas-dev/pandas/pull/47613  1296064099
# 23  https://github.com/pandas-dev/pandas/issues/47608  1295610501
# 24  https://github.com/pandas-dev/pandas/issues/47607  1295265525
# 25    https://github.com/pandas-dev/pandas/pull/47605  1295119659
# 26  https://github.com/pandas-dev/pandas/issues/47604  1294984836
# 27    https://github.com/pandas-dev/pandas/pull/47603  1294888314
# 28    https://github.com/pandas-dev/pandas/pull/47602  1294804051
# 29    https://github.com/pandas-dev/pandas/pull/47598  1294298140
#
#                 node_id  number  \
# 0   PR_kwDOAA0YD847NjCK   47669
# 1   PR_kwDOAA0YD847MrBD   47668
# 2    I_kwDOAA0YD85Nh9Vs   47667
# 3    I_kwDOAA0YD85NgyUp   47666
# 4    I_kwDOAA0YD85NfXCL   47663
# 5    I_kwDOAA0YD85NeYxf   47659
# 6   PR_kwDOAA0YD847Jc8C   47658
# 7   PR_kwDOAA0YD847Ja_a   47657
# 8   PR_kwDOAA0YD847JW6r   47656
# 9    I_kwDOAA0YD85Nd_wM   47653
# 10   I_kwDOAA0YD85Nd4r-   47651
# 11   I_kwDOAA0YD85NdZ46   47649
# 12  PR_kwDOAA0YD847IPLG   47647
# 13  PR_kwDOAA0YD847ILj0   47645
# 14  PR_kwDOAA0YD847H1Zt   47643
# 15   I_kwDOAA0YD85NbPHG   47639
# 16   I_kwDOAA0YD85NX8ZV   47629
# 17   I_kwDOAA0YD85NXvPd   47628
# 18   I_kwDOAA0YD85NVWpI   47625
# 19  PR_kwDOAA0YD847BHZJ   47624
# 20   I_kwDOAA0YD85NUFTo   47622
# 21   I_kwDOAA0YD85NQWUG   47614
# 22  PR_kwDOAA0YD8468wdY   47613
# 23   I_kwDOAA0YD85NOXKF   47608
# 24   I_kwDOAA0YD85NNC71   47607
# 25  PR_kwDOAA0YD8465ghB   47605
# 26   I_kwDOAA0YD85NL-aE   47604
# 27  PR_kwDOAA0YD8464u7M   47603
# 28  PR_kwDOAA0YD8464cfj   47602
# 29  PR_kwDOAA0YD8462wob   47598
#
#                                                 title  ... closed_at  \
# 0                         ENH: Add reversed to Series  ...      None
# 1                   ENH: TDA.__mul__ support non-nano  ...      None
# 2   BUG: caching in CachedAccessor is problematic ...  ...      None
# 3   ENH: rolling mean with limited number of obser...  ...      None
# 4   Why does `index.fillna()` have different argum...  ...      None
# 5   BUG: read_json broken for S3 URL with non-null...  ...      None
# 6   ENH: GH19708 - Index now has diff and round me...  ...      None
# 7           ENH - Add index parameter do df.to_dict()  ...      None
# 8   SAS7BDAT parser: Improve subheader lookup perf...  ...      None
# 9            BUG: Grouper: Origin param has no effect  ...      None
# 10  DOC: Weekday incompatibility with Python’s dem...  ...      None
# 11  BUG: multi-index df fillna with value not work...  ...      None
# 12  BUG: #47350 if else added to add NaT for missi...  ...      None
# 13   ENH/TST: Add TestBaseArithmeticOps tests for ...  ...      None
# 14  ENH: add suffixes argument to DataFrame.compar...  ...      None
# 15           BUG: `fillna` cannot convert NaN to None  ...      None
# 16  pd.eval not correctly evaluating equality of l...  ...      None
# 17  BUG: Inconsistent behavior between `None` and ...  ...      None
# 18  BUG: mdates.DateFormatter ignores timezone in ...  ...      None
# 19   ENH: Make categories setitem error more readable  ...      None
# 20  BUG: `Period` and `period_range` behaviour is ...  ...      None
# 21  PERF: cut with IntervalIndex slower than cut w...  ...      None
# 22  Fix Period not using freq when using same base...  ...      None
# 23  BUG: inconsistent index between plain DataFram...  ...      None
# 24  BUG: MultiIndex level not sorted (as desired) ...  ...      None
# 25  BUG: df.groupby().resample()[[cols]] without k...  ...      None
# 26  ENH: Display DataFrame column dtypes (data typ...  ...      None
# 27  Add test for unique aggregation returning diff...  ...      None
# 28  BUG: Make xticks from _quarterly_finder() line...  ...      None
# 29  BUG: `pd.period_range` ignores multiple of `st...  ...      None
#
#    author_association active_lock_reason  draft  \
# 0         CONTRIBUTOR               None   True
# 1              MEMBER               None  False
# 2         CONTRIBUTOR               None    NaN
# 3                NONE               None    NaN
# 4         CONTRIBUTOR               None    NaN
# 5                NONE               None    NaN
# 6                NONE               None  False
# 7                NONE               None  False
# 8         CONTRIBUTOR               None  False
# 9                NONE               None    NaN
# 10               NONE               None    NaN
# 11        CONTRIBUTOR               None    NaN
# 12               NONE               None  False
# 13             MEMBER               None  False
# 14        CONTRIBUTOR               None  False
# 15        CONTRIBUTOR               None    NaN
# 16               NONE               None    NaN
# 17        CONTRIBUTOR               None    NaN
# 18               NONE               None    NaN
# 19               NONE               None  False
# 20               NONE               None    NaN
# 21               NONE               None    NaN
# 22               NONE               None   True
# 23               NONE               None    NaN
# 24               NONE               None    NaN
# 25        CONTRIBUTOR               None  False
# 26               NONE               None    NaN
# 27        CONTRIBUTOR               None  False
# 28               NONE               None  False
# 29               NONE               None  False
#
#                                          pull_request  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20                                                NaN
# 21                                                NaN
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23                                                NaN
# 24                                                NaN
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26                                                NaN
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                                  body  \
# 0   Add Reversed so that it fulfills all propertie...
# 1   - [ ] closes #xxxx (Replace xxxx with the Gith...
# 2   ### Pandas version checks\r\n\r\n- [X] I have ...
# 3   #### Is your feature request related to a prob...
# 4   In particular, why can't `index.fillna()` have...
# 5   ### Pandas version checks\r\n\r\n- [X] I have ...
# 6   - [X] closes #19708 \r\n- [ ] [Tests added and...
# 7   - [x] closes #46398\r\n- [x] [Tests added and ...
# 8   Avoid constructing `_SubheaderPointer` objects...
# 9   ### Pandas version checks\n\n- [X] I have chec...
# 10  ### Pandas version checks\n\n- [X] I have chec...
# 11  ### Pandas version checks\n\n- [X] I have chec...
# 12  If else added to add NaT rows for missing time...
# 13  - [x] [Tests added and passed](https://pandas....
# 14  This is following up on the pull request #4436...
# 15  ### Pandas version checks\n\n- [X] I have chec...
# 16  Hi,\r\n\r\nThe following evaluates False when ...
# 17  ### Pandas version checks\r\n\r\n- [X] I have ...
# 18  ### Pandas version checks\n\n- [x] I have chec...
# 19                                      Closes #46646
# 20  ### Pandas version checks\r\n\r\n- [X] I have ...
# 21  ### Pandas version checks\n\n- [X] I have chec...
# 22  - [ ] closes #xxxx (Replace xxxx with the Gith...
# 23  ### Pandas version checks\n\n- [X] I have chec...
# 24  ### Pandas version checks\r\n\r\n- [X] I have ...
# 25  - [x] closes #47362\r\n- [x] [Tests added and ...
# 26  #### Is your feature request related to a prob...
# 27  - [ ] closes #22558 (Replace xxxx with the Git...
# 28  When I plot a series of quarterly data that sp...
# 29  Fixes: #47465\r\n\r\n- [x] closes #47465\r\n- ...
#
#                                             reactions  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                          timeline_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#    performed_via_github_app state_reason
# 0                      None         None
# 1                      None         None
# 2                      None         None
# 3                      None         None
# 4                      None         None
# 5                      None         None
# 6                      None         None
# 7                      None         None
# 8                      None         None
# 9                      None         None
# 10                     None         None
# 11                     None         None
# 12                     None         None
# 13                     None         None
# 14                     None         None
# 15                     None         None
# 16                     None         None
# 17                     None         None
# 18                     None         None
# 19                     None         None
# 20                     None         None
# 21                     None         None
# 22                     None         None
# 23                     None         None
# 24                     None         None
# 25                     None         None
# 26                     None         None
# 27                     None         None
# 28                     None         None
# 29                     None         None
#
# [30 rows x 30 columns]
