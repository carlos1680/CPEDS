# %%
import pandas as pd
import datetime as dt
import numpy as np

pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# # Consigna
#
# Vamos a continuar trabajando con el dataset de la encuesta de sueldos en el sector tecnológico.
#
# En esta oportunidad vamos a analizar la calidad de la información brindada. Nos interesa saber:
#
# - si existen registros duplicados
#
# - si existen datos faltantes: analizar especificamente las variables *tenes_algun_tipo_de_discapacidad* y *salario_mensual_neto_en_tu_moneda_local*; nos interesa imputar los faltantes en ambos casos
#
# - si nuesta información es consistente tanto interna como externamente
#
# Para el ultimo punto se sugiere:
#
# - cruzar la edad con los años de experiencia (validez interna)
#
# - cruzar la experiencia con los años en la experiencia actual (validez interna)
#
# - comparar salario bruto con salario neto (validez interna)
#
# - cruzar el sueldo percibido con el sueldo mínimo vigente (validez externa). TIP: usar solo los casos de Argentina (salario mínimo vigente para 2020: $16.875,0)

# %%
sueldos = pd.read_csv("https://raw.githubusercontent.com/eea-uba/EEA-2020/master/Fuentes/encuesta_sueldos_sysarmy_1s2020.csv")
sueldos.head()
# Out:
#             timestamp me_identifico  tengo estoy_trabajando_en  \
# 0   1/31/2020 6:50:26        Hombre     32           Argentina
# 1   1/28/2020 9:27:48        Hombre     30           Argentina
# 2  1/29/2020 16:54:29         Mujer     40           Argentina
# 3    2/1/2020 5:46:25         Mujer     36           Argentina
# 4   2/1/2020 17:51:21        Hombre     29           Argentina
#
#             donde_estas_trabajando  anos_de_experiencia  \
# 0  Ciudad Autónoma de Buenos Aires                   10
# 1  Ciudad Autónoma de Buenos Aires                    3
# 2  Ciudad Autónoma de Buenos Aires                   15
# 3  Ciudad Autónoma de Buenos Aires                   10
# 4  Ciudad Autónoma de Buenos Aires                   10
#
#    anos_en_la_empresa_actual  anos_en_el_puesto_actual gente_a_cargo  \
# 0                          3                         1             0
# 1                          3                         3             0
# 2                          3                         3             1
# 3                          3                         3             0
# 4                          2                         2             0
#
#   nivel_de_estudios_alcanzado  ... sos_miembro_de_alguna_comunidad_it  \
# 0                  Secundario  ...                                NaN
# 1                   Terciario  ...                                NaN
# 2               Universitario  ...                                NaN
# 3               Universitario  ...                                NaN
# 4               Universitario  ...                                NaN
#
#   cantidad_de_empleados                            actividad_principal  \
# 0                10001+                    Producto basado en Software
# 1                51-100                               Otras industrias
# 2                 11-50  Servicios / Consultoría de Software / Digital
# 3                51-100                               Otras industrias
# 4                 11-50                               Otras industrias
#
#   la_recomendas_como_un_buen_lugar_para_trabajar  \
# 0                                              8
# 1                                              7
# 2                                              8
# 3                                              7
# 4                                              5
#
#   como_calificas_las_politicas_de_diversidad_e_inclusion  \
# 0                                                 10
# 1                                                  3
# 2                                                  8
# 3                                                  5
# 4                                                  8
#
#   a_cuantos_kilometros_de_tu_casa_queda_la_oficina  \
# 0                                                6
# 1                                               35
# 2                                               30
# 3                                                4
# 4                                                7
#
#                                     beneficios_extra  \
# 0  Capacitaciones y/o cursos, Comidas pagas / sub...
# 1                          Capacitaciones y/o cursos
# 2  Abono de celular y/o Internet, Capacitaciones ...
# 3                                           Viáticos
# 4                          Ninguna de las anteriores
#
#   habias_respondido_nuestra_encuesta_en_ediciones_anteriores  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   cuales_consideras_que_son_las_mejores_empresas_de_it_para_trabajar_en_este_momentoen_tu_ciudad  \
# 0                                         cognizant
# 1                                       mercadolibre
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   sueldo_dolarizado
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
#
# [5 rows x 53 columns]

# %% [markdown]
# ## 1) Duplicados

# %%
# Validamos si hay registros duplicados
sueldos.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 2) Faltantes

# %%
sueldos.isnull().sum()
# Out:
# timestamp                                                                                            0
# me_identifico                                                                                        0
# tengo                                                                                                0
# estoy_trabajando_en                                                                                  0
# donde_estas_trabajando                                                                               0
# anos_de_experiencia                                                                                  0
# anos_en_la_empresa_actual                                                                            0
# anos_en_el_puesto_actual                                                                             0
# gente_a_cargo                                                                                        0
# nivel_de_estudios_alcanzado                                                                          0
# estado                                                                                               0
# carrera                                                                                            338
# universidad                                                                                        626
# realizaste_cursos_de_especializacion                                                                 0
# contribuis_a_proyectos_open_source                                                                   0
# programas_como_hobbie                                                                                0
# trabajo_de                                                                                           0
# plataformas                                                                                       1098
# lenguajes_de_programacion                                                                         1102
# frameworksherramientas_y_librerias                                                                2319
# bases_de_datos                                                                                    1483
# qa_testing                                                                                        3803
# ides                                                                                              1704
# que_so_usas_en_tu_laptoppc_para_trabajar                                                             0
# y_en_tu_celular                                                                                      0
# tenes_guardias                                                                                       0
# cuanto_cobras_por_guardia                                                                            0
# porcentajebruto_o_neto                                                                               0
# tipo_de_contrato                                                                                     0
# salario_mensual_bruto_en_tu_moneda_local                                                             0
# salario_mensual_neto_en_tu_moneda_local                                                            214
# que_tan_conforme_estas_con_tu_sueldo                                                                 0
# como_crees_que_esta_tu_sueldo_con_respecto_al_ultimo_semestre                                        0
# recibis_algun_tipo_de_bono                                                                           0
# a_que_esta_atado_el_bono                                                                             0
# tuviste_ajustes_por_inflacion_en_2019                                                                0
# de_que_fue_el_ajuste_total                                                                           0
# en_que_mes_fue_el_ultimo_ajuste                                                                      0
# sufriste_o_presenciaste_situaciones_de_violencia_laboral                                            50
# orientacion_sexual                                                                                 112
# tenes_algun_tipo_de_discapacidad                                                                  5562
# sentis_que_esto_te_dificulto_el_conseguir_trabajo                                                 3019
# a_que_eventos_de_tecnologia_asististe_en_el_ultimo_ano                                            3864
# sos_miembro_de_alguna_comunidad_it                                                                4512
# cantidad_de_empleados                                                                                0
# actividad_principal                                                                                  0
# la_recomendas_como_un_buen_lugar_para_trabajar                                                       0
# como_calificas_las_politicas_de_diversidad_e_inclusion                                               0
# a_cuantos_kilometros_de_tu_casa_queda_la_oficina                                                     0
# beneficios_extra                                                                                     0
# habias_respondido_nuestra_encuesta_en_ediciones_anteriores                                           0
# cuales_consideras_que_son_las_mejores_empresas_de_it_para_trabajar_en_este_momentoen_tu_ciudad    4294
# sueldo_dolarizado                                                                                    0
# dtype: int64

# %%
# Analizamos los posibles valores de la variable tenes_algun_tipo_de_discapacidad
sueldos.tenes_algun_tipo_de_discapacidad.unique()
# Out:
# array([nan, 'Visual', 'Auditiva', 'Motriz', 'Verbal', 'Epilepsia',
#        'Diabetes ', '.', 'No ninguna', 'Mental', 'Dislexia',
#        'uso anteojos', 'N8bguna', 'Edad', 'n9', 'Programador',
#        'Faltó la opción Ninguna', 'que te importa gil', 'Depresión',
#        'Visceral', 'Epilepsia ', 'ADHD (ADD) y Tourette', 'Tartamudez',
#        'Problemas en la voz (Disfonia)', 'N0', 'Migraña crónica ',
#        'Debería haber opciones de respetar su privacidad',
#        'Atigmatismo y miopía, pero puedo ver :)', 'Posible Asperger',
#        'Obesidad', 'tendinitis en las manos', 'Migrañas Crónicas'],
#       dtype=object)

# %%
# imputamos como "no" a aquellos valores sin responder
sueldos['tenes_algun_tipo_de_discapacidad_fill'] = sueldos['tenes_algun_tipo_de_discapacidad'].fillna('NO')

# %%
sueldos.tenes_algun_tipo_de_discapacidad_fill.isnull().sum()
# Out:
# 0

# %%
# Para la variable salario_mensual_neto_en_tu_moneda_local, imputamos la mediana en los datos faltantes
mediana_sueldo_neto = sueldos['salario_mensual_neto_en_tu_moneda_local'].median()

sueldos['salario_mensual_neto_en_tu_moneda_local_fill'] = sueldos['salario_mensual_neto_en_tu_moneda_local'].fillna(mediana_sueldo_neto)

# %%
mediana_sueldo_neto
# Out:
# 60000.0

# %%
sueldos.salario_mensual_neto_en_tu_moneda_local_fill.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## 3) *Sanity Check*
#
# * cruzar la edad con los años de experiencia (validez interna)
#
# * cruzar la experiencia con los años en la experiencia actual (validez interna)
#
# * comparar salario bruto con salario neto (validez interna)
#
# * cruzar el sueldo percibido con el sueldo mínimo vigente (validez externa). TIP: usar solo los casos de Argentina (salario mínimo vigente para 2020: $16.875,0)
#
# Para esta parte vamos a utilizar unicamente los salarios de Argentina.

# %%
sueldos = sueldos[sueldos.estoy_trabajando_en == 'Argentina']

# %% [markdown]
# ### a) cruzar la edad con los años de experiencia (validez interna)

# %%
sueldos.tengo.head()
# Out:
# 0    32
# 1    30
# 2    40
# 3    36
# 4    29
# Name: tengo, dtype: int64

# %%
# calculo la edad en que la persona empezo a trabajar de acuerdo a lo declarado
sueldos['empieza_trabajar'] = sueldos.tengo - sueldos.anos_de_experiencia

# %%
print(min(sueldos['empieza_trabajar']), max(sueldos['empieza_trabajar']))
# Out:
# -37 57

# %%
# marcamos aquellos casos en los cuales la edad en la cual empezó a trabajar es inferior a los 17 años
sueldos['inconsistencia_experiencia'] = np.where(sueldos['empieza_trabajar'] < 17, 1, 0)

# %%
sueldos[sueldos['inconsistencia_experiencia'] == 1].head()
# Out:
#               timestamp me_identifico  tengo estoy_trabajando_en  \
# 23   1/30/2020 12:10:43        Hombre     24           Argentina
# 206    2/1/2020 0:18:11        Hombre     45           Argentina
# 207    2/1/2020 9:55:12        Hombre     40           Argentina
# 222   2/2/2020 20:24:25        Hombre     39           Argentina
# 291   1/1/2020 12:14:23         Mujer     27           Argentina
#
#               donde_estas_trabajando  anos_de_experiencia  \
# 23   Ciudad Autónoma de Buenos Aires                    8
# 206  Ciudad Autónoma de Buenos Aires                   30
# 207  Ciudad Autónoma de Buenos Aires                   24
# 222                     Buenos Aires                   25
# 291                          Córdoba                   25
#
#      anos_en_la_empresa_actual  anos_en_el_puesto_actual gente_a_cargo  \
# 23                           6                         2             0
# 206                          3                         3            10
# 207                          1                         1             0
# 222                          5                         5             0
# 291                         25                         1             0
#
#     nivel_de_estudios_alcanzado  ...  \
# 23                    Terciario  ...
# 206               Universitario  ...
# 207                  Secundario  ...
# 222               Universitario  ...
# 291               Universitario  ...
#
#     como_calificas_las_politicas_de_diversidad_e_inclusion  \
# 23                                                   3
# 206                                                  8
# 207                                                 10
# 222                                                 10
# 291                                                  7
#
#     a_cuantos_kilometros_de_tu_casa_queda_la_oficina  \
# 23                                                 7
# 206                                               20
# 207                                               35
# 222                                                5
# 291                                                2
#
#                                       beneficios_extra  \
# 23   Capacitaciones y/o cursos, Cuota para universi...
# 206  Capacitaciones y/o cursos, Vacaciones flexible...
# 207                                 Horarios flexibles
# 222  Abono de celular y/o Internet, Comidas pagas /...
# 291  Capacitaciones y/o cursos, Clases de idiomas, ...
#
#     habias_respondido_nuestra_encuesta_en_ediciones_anteriores  \
# 23                                                  No
# 206                                                 No
# 207                                                 No
# 222                                                 No
# 291                                                 No
#
#     cuales_consideras_que_son_las_mejores_empresas_de_it_para_trabajar_en_este_momentoen_tu_ciudad  \
# 23                                                   -
# 206                                           Mulesoft
# 207                                                NaN
# 222                                      Watcha S.A.S.
# 291                                                NaN
#
#     sueldo_dolarizado tenes_algun_tipo_de_discapacidad_fill  \
# 23              False                                    NO
# 206             False                                    NO
# 207             False                                    NO
# 222             False                                    NO
# 291              True                                    NO
#
#     salario_mensual_neto_en_tu_moneda_local_fill empieza_trabajar  \
# 23                                       31300.0               16
# 206                                      75000.0               15
# 207                                      74000.0               16
# 222                                       5000.0               14
# 291                                      45000.0                2
#
#     inconsistencia_experiencia
# 23                           1
# 206                          1
# 207                          1
# 222                          1
# 291                          1
#
# [5 rows x 57 columns]

# %% [markdown]
# ### b) cruzar la experiencia con los años en la experiencia actual (validez interna)

# %%
sueldos['inconsistencia_experiencia_trabajo_actual'] = np.where(sueldos['anos_de_experiencia'] < sueldos['anos_en_la_empresa_actual'], 1, 0)

# %%
sueldos[sueldos['inconsistencia_experiencia_trabajo_actual'] == 1].head()
# Out:
#              timestamp me_identifico  tengo estoy_trabajando_en  \
# 21  12/31/2019 1:05:01        Hombre     32           Argentina
# 25   2/1/2020 14:35:24         Mujer     22           Argentina
# 26   2/1/2020 14:40:00         Mujer     52           Argentina
# 42   1/9/2020 12:20:46        Hombre     26           Argentina
# 63   2/1/2020 14:43:05         Mujer     43           Argentina
#
#              donde_estas_trabajando  anos_de_experiencia  \
# 21                     Buenos Aires                    7
# 25  Ciudad Autónoma de Buenos Aires                    2
# 26  Ciudad Autónoma de Buenos Aires                   22
# 42  Ciudad Autónoma de Buenos Aires                    6
# 63  Ciudad Autónoma de Buenos Aires                    3
#
#     anos_en_la_empresa_actual  anos_en_el_puesto_actual gente_a_cargo  \
# 21                         13                         7             3
# 25                          3                         2             0
# 26                         23                        10             0
# 42                          8                         4             0
# 63                         13                         3             1
#
#    nivel_de_estudios_alcanzado  ...  \
# 21               Universitario  ...
# 25               Universitario  ...
# 26                  Secundario  ...
# 42               Universitario  ...
# 63                   Terciario  ...
#
#    a_cuantos_kilometros_de_tu_casa_queda_la_oficina  \
# 21                                                9
# 25                                               15
# 26                                                7
# 42                                               15
# 63                                                8
#
#                                      beneficios_extra  \
# 21  Abono de celular y/o Internet, Vacaciones flex...
# 25  Capacitaciones y/o cursos, Guardería, Lactario...
# 26        Licencia de paternidad/maternidad extendida
# 42                          Capacitaciones y/o cursos
# 63  Comidas pagas / subvencionadas, Horarios flexi...
#
#    habias_respondido_nuestra_encuesta_en_ediciones_anteriores  \
# 21                                                 Sí
# 25                                                 No
# 26                                                 No
# 42                                                 No
# 63                                                 No
#
#    cuales_consideras_que_son_las_mejores_empresas_de_it_para_trabajar_en_este_momentoen_tu_ciudad  \
# 21                                       Mercadolibre
# 25                                                  0
# 26                                                NaN
# 42                  EY, JP Morgan, Accenture, Techint
# 63                               Despegar, telefonica
#
#    sueldo_dolarizado tenes_algun_tipo_de_discapacidad_fill  \
# 21             False                                    NO
# 25             False                                    NO
# 26             False                                    NO
# 42             False                                    NO
# 63             False                                    NO
#
#    salario_mensual_neto_en_tu_moneda_local_fill empieza_trabajar  \
# 21                                      58000.0               25
# 25                                      37000.0               20
# 26                                      24000.0               30
# 42                                      70000.0               20
# 63                                         58.0               40
#
#    inconsistencia_experiencia inconsistencia_experiencia_trabajo_actual
# 21                          0                                         1
# 25                          0                                         1
# 26                          0                                         1
# 42                          0                                         1
# 63                          0                                         1
#
# [5 rows x 58 columns]

# %% [markdown]
# ### c) comparar salario bruto con salario neto (validez interna)

# %%
sueldos['inconsistencia_salario_bruto_neto'] = np.where(sueldos['salario_mensual_bruto_en_tu_moneda_local'] < sueldos['salario_mensual_neto_en_tu_moneda_local'], 1, 0)

# %%
sueldos[sueldos['inconsistencia_salario_bruto_neto'] == 1].head()
# Out:
#               timestamp me_identifico  tengo estoy_trabajando_en  \
# 13    2/2/2020 19:01:32         Mujer     42           Argentina
# 24   1/31/2020 18:45:21         Mujer     22           Argentina
# 76   1/31/2020 20:41:51        Hombre     24           Argentina
# 97   12/15/2019 0:56:50        Hombre     43           Argentina
# 126   1/4/2020 15:59:23        Hombre     27           Argentina
#
#               donde_estas_trabajando  anos_de_experiencia  \
# 13   Ciudad Autónoma de Buenos Aires                   15
# 24   Ciudad Autónoma de Buenos Aires                    1
# 76   Ciudad Autónoma de Buenos Aires                    1
# 97                          Santa Fe                   14
# 126  Ciudad Autónoma de Buenos Aires                    7
#
#      anos_en_la_empresa_actual  anos_en_el_puesto_actual gente_a_cargo  \
# 13                          11                        11             0
# 24                           1                         1             0
# 76                           0                         0             0
# 97                          11                         2             0
# 126                          1                         1             5
#
#     nivel_de_estudios_alcanzado  ...  \
# 13                Universitario  ...
# 24                Universitario  ...
# 76                    Terciario  ...
# 97                Universitario  ...
# 126               Universitario  ...
#
#                                       beneficios_extra  \
# 13                                           Guardería
# 24                                  Horarios flexibles
# 76   Capacitaciones y/o cursos, Descuentos varios (...
# 97   Capacitaciones y/o cursos, Horarios flexibles,...
# 126  Capacitaciones y/o cursos, Gimnasios gratuitos...
#
#     habias_respondido_nuestra_encuesta_en_ediciones_anteriores  \
# 13                                                  No
# 24                                                  No
# 76                                                  No
# 97                                                  Sí
# 126                                                 No
#
#     cuales_consideras_que_son_las_mejores_empresas_de_it_para_trabajar_en_este_momentoen_tu_ciudad  \
# 13                                                 NaN
# 24                                                 NaN
# 76                                               no se
# 97                                          Nemogroup
# 126                                                NaN
#
#     sueldo_dolarizado tenes_algun_tipo_de_discapacidad_fill  \
# 13              False                                    NO
# 24              False                                    NO
# 76              False                                    NO
# 97              False                                    NO
# 126             False                                    NO
#
#     salario_mensual_neto_en_tu_moneda_local_fill empieza_trabajar  \
# 13                                       24000.0               27
# 24                                       18000.0               21
# 76                                      392175.0               23
# 97                                       75000.0               29
# 126                                      74000.0               20
#
#     inconsistencia_experiencia inconsistencia_experiencia_trabajo_actual  \
# 13                           0                                         0
# 24                           0                                         0
# 76                           0                                         0
# 97                           0                                         0
# 126                          0                                         0
#
#     inconsistencia_salario_bruto_neto
# 13                                  1
# 24                                  1
# 76                                  1
# 97                                  1
# 126                                 1
#
# [5 rows x 59 columns]

# %% [markdown]
# ### d) cruzar el sueldo percibido con el sueldo mínimo vigente (validez externa)

# %%
sueldos['inconsistencia_salario_minimo'] = np.where(sueldos['salario_mensual_bruto_en_tu_moneda_local'] < 16875, 1, 0)

# %%
sueldos[sueldos['inconsistencia_salario_minimo'] == 1].head()
# Out:
#              timestamp me_identifico  tengo estoy_trabajando_en  \
# 0    1/31/2020 6:50:26        Hombre     32           Argentina
# 7    2/2/2020 11:46:48        Hombre     24           Argentina
# 13   2/2/2020 19:01:32         Mujer     42           Argentina
# 20  1/29/2020 13:57:21        Hombre     22           Argentina
# 24  1/31/2020 18:45:21         Mujer     22           Argentina
#
#              donde_estas_trabajando  anos_de_experiencia  \
# 0   Ciudad Autónoma de Buenos Aires                   10
# 7   Ciudad Autónoma de Buenos Aires                    2
# 13  Ciudad Autónoma de Buenos Aires                   15
# 20  Ciudad Autónoma de Buenos Aires                    1
# 24  Ciudad Autónoma de Buenos Aires                    1
#
#     anos_en_la_empresa_actual  anos_en_el_puesto_actual gente_a_cargo  \
# 0                           3                         1             0
# 7                           2                         2             0
# 13                         11                        11             0
# 20                          1                         1             0
# 24                          1                         1             0
#
#    nivel_de_estudios_alcanzado  ...  \
# 0                   Secundario  ...
# 7                   Secundario  ...
# 13               Universitario  ...
# 20               Universitario  ...
# 24               Universitario  ...
#
#    habias_respondido_nuestra_encuesta_en_ediciones_anteriores  \
# 0                                                  No
# 7                                                  No
# 13                                                 No
# 20                                                 No
# 24                                                 No
#
#    cuales_consideras_que_son_las_mejores_empresas_de_it_para_trabajar_en_este_momentoen_tu_ciudad  \
# 0                                          cognizant
# 7                                                 NaN
# 13                                                NaN
# 20                                                NaN
# 24                                                NaN
#
#    sueldo_dolarizado tenes_algun_tipo_de_discapacidad_fill  \
# 0              False                                    NO
# 7              False                                    NO
# 13             False                                    NO
# 20             False                                    NO
# 24             False                                    NO
#
#    salario_mensual_neto_en_tu_moneda_local_fill empieza_trabajar  \
# 0                                          40.0               22
# 7                                          22.0               22
# 13                                      24000.0               27
# 20                                      10000.0               21
# 24                                      18000.0               21
#
#    inconsistencia_experiencia inconsistencia_experiencia_trabajo_actual  \
# 0                           0                                         0
# 7                           0                                         0
# 13                          0                                         0
# 20                          0                                         0
# 24                          0                                         0
#
#    inconsistencia_salario_bruto_neto inconsistencia_salario_minimo
# 0                                  0                             1
# 7                                  0                             1
# 13                                 1                             1
# 20                                 0                             1
# 24                                 1                             1
#
# [5 rows x 60 columns]

# %% [markdown]
# ### Validación final

# %%
registros_raw = len(sueldos)
registros_clean = len(sueldos[(sueldos.inconsistencia_experiencia < 1) &
                  (sueldos.inconsistencia_experiencia_trabajo_actual < 1) &
                  (sueldos.inconsistencia_salario_bruto_neto < 1) &
                  (sueldos.inconsistencia_salario_minimo < 1)])
diferencia = registros_raw - registros_clean

# %%
print("""Previo a la limipeza, el dataset presenta {} registros para Argentina. Luego de aplicar los filtros para 
quitar los registros con inconsistencias, se conservan {} registros habiendo eliminado {} observaciones.""".format(registros_raw, registros_clean, diferencia))
# Out:
# Previo a la limipeza, el dataset presenta 5982 registros para Argentina. Luego de aplicar los filtros para
# quitar los registros con inconsistencias, se conservan 5358 registros habiendo eliminado 624 observaciones.
